# %% [markdown]
# <a href="https://colab.research.google.com/github/yasawnthbalaji/python-dsa-practice/blob/main/DSA_PRACTICE_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str  = input("Enter string : ")
rev = str[::-1]
print(rev)
# Out:
# Enter string : python
# nohtyp

# %%
i = input("Enter string : ")
if i == i[::-1]:
    print(i," is an palindrome")
else:
    print(i," is not an palindrome")
# Out:
# Enter string : huh
# huh  is an palindrome
